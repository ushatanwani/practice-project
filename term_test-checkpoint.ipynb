# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings ('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
#import scikitlearn as scipy
from scipy import stats

# %%
df=pd.read_csv("term_test.csv")

# %%
df.head()
# Out:
#       ID  age            job   marital  education default  balance housing  \
# 0  38441   32       services   married  secondary      no      118     yes
# 1  40403   78        retired  divorced    primary      no     2787      no
# 2   3709   31  self-employed    single   tertiary      no      144     yes
# 3  37422   57       services    single    primary      no     3777     yes
# 4  12527   45    blue-collar  divorced  secondary      no     -705      no
#
#   loan    contact  day month  duration  campaign  pdays  previous poutcome
# 0   no   cellular   15   may        20         6     -1         0  unknown
# 1   no  telephone    1   jul       372         1     -1         0  unknown
# 2   no    unknown   16   may       676         1     -1         0  unknown
# 3   no  telephone   13   may        65         2     -1         0  unknown
# 4  yes    unknown    3   jul       111         1     -1         0  unknown

# %%
df.shape
# Out:
# (13564, 17)

# %%
df.isnull().sum()
# Out:
# ID           0
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# dtype: int64

# %%
df['poutcome'].unique()
# Out:
# array(['unknown', 'failure', 'other', 'success'], dtype=object)

# %%
df['job'].nunique()
# Out:
# 12

# %%
df['day'].unique()
# Out:
# array([15,  1, 16, 13,  3, 22,  5,  2, 25, 21,  7,  9,  6,  4, 14, 27,  8,
#        30, 28, 31, 29, 10, 23, 26, 12, 17, 20, 11, 19, 18, 24],
#       dtype=int64)

# %%
df['education'].nunique()
# Out:
# 4

# %%
df.dtypes
# Out:
# ID            int64
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# dtype: object

# %%
df.describe()
# Out:
#                  ID           age       balance           day      duration  \
# count  13564.000000  13564.000000  13564.000000  13564.000000  13564.000000
# mean   22704.057726     40.887128   1358.496535     15.738646    258.278679
# std    12994.043329     10.604108   3082.940623      8.288174    258.488648
# min        1.000000     18.000000  -3313.000000      1.000000      0.000000
# 25%    11546.000000     33.000000     71.000000      8.000000    102.000000
# 50%    22782.000000     39.000000    445.000000     16.000000    180.000000
# 75%    33974.250000     48.000000   1413.250000     21.000000    319.000000
# max    45206.000000     95.000000  98417.000000     31.000000   3253.000000
#
#            campaign         pdays      previous
# count  13564.000000  13564.000000  13564.000000
# mean       2.759510     41.648555      0.594441
# std        3.060928    101.985178      1.998193
# min        1.000000     -1.000000      0.000000
# ...

# %%
df.shape
# Out:
# (13564, 17)

# %%
df.columns
# Out:
# Index(['ID', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome'],
#       dtype='object')

# %%
df['marital'].nunique()
# Out:
# 3

# %%
df['poutcome'].value_counts()
# Out:
# unknown    11030
# failure     1539
# other        552
# success      443
# Name: poutcome, dtype: int64

# %%
df.skew()
# Out:
# ID         -0.013625
# age         0.692404
# balance     9.165015
# day         0.106806
# duration    3.017221
# campaign    4.958236
# pdays       2.555601
# previous    8.704583
# dtype: float64

# %%
sns.countplot(df['marital'])
# Out:
# <AxesSubplot:xlabel='marital', ylabel='count'>

# %%
sns.countplot(df['job'])
# Out:
# <AxesSubplot:xlabel='job', ylabel='count'>

# %%
sns.countplot(df['education'])
# Out:
# <AxesSubplot:xlabel='education', ylabel='count'>

# %%
sns.countplot(df['month'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='count'>

# %%
df['job'].value_counts()
# Out:
# blue-collar      2890
# management       2819
# technician       2290
# admin.           1540
# services         1251
# retired           690
# entrepreneur      479
# self-employed     456
# unemployed        398
# housemaid         366
# student           303
# unknown            82
# Name: job, dtype: int64

# %%
plt.boxplot(df['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2bac3b19100>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2bac3b196d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2bac3c8bdc0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2bac3b19c70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2bac3b19f40>],
#  'means': []}

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))
# Out:
# ID             AxesSubplot(0.125,0.53;0.110714x0.35)
# age         AxesSubplot(0.257857,0.53;0.110714x0.35)
# balance     AxesSubplot(0.390714,0.53;0.110714x0.35)
# day         AxesSubplot(0.523571,0.53;0.110714x0.35)
# duration    AxesSubplot(0.656429,0.53;0.110714x0.35)
# campaign    AxesSubplot(0.789286,0.53;0.110714x0.35)
# pdays          AxesSubplot(0.125,0.11;0.110714x0.35)
# previous    AxesSubplot(0.257857,0.11;0.110714x0.35)
# dtype: object

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                 ID       age   balance       day  duration  campaign  \
# ID        1.000000  0.018874  0.086916 -0.056813  0.026686 -0.101389
# age       0.018874  1.000000  0.085246 -0.004622 -0.006456  0.002439
# balance   0.086916  0.085246  1.000000  0.006890  0.015375 -0.020524
# day      -0.056813 -0.004622  0.006890  1.000000 -0.025344  0.170421
# duration  0.026686 -0.006456  0.015375 -0.025344  1.000000 -0.094653
# campaign -0.101389  0.002439 -0.020524  0.170421 -0.094653  1.000000
# pdays     0.441437 -0.027797  0.007136 -0.105314 -0.006308 -0.091116
# previous  0.321845 -0.011326  0.024824 -0.060719 -0.000415 -0.032366
#
#              pdays  previous
# ID        0.441437  0.321845
# age      -0.027797 -0.011326
# balance   0.007136  0.024824
# day      -0.105314 -0.060719
# duration -0.006308 -0.000415
# campaign -0.091116 -0.032366
# pdays     1.000000  0.534085
# previous  0.534085  1.000000

# %%
import sklearn
from sklearn import preprocessing
le=preprocessing.LabelEncoder()


df["job"]=le.fit_transform(df['job'])

# %%
df['marital']=le.fit_transform(df['marital'])
df['education']=le.fit_transform(df['education'])
df['default']=le.fit_transform(df['default'])
df['housing']=le.fit_transform(df['housing'])
df['loan']=le.fit_transform(df['loan'])
df['contact']=le.fit_transform(df['contact'])
df['month']=le.fit_transform(df['month'])
df['poutcome']=le.fit_transform(df['poutcome'])

# %%
import scipy.stats
from scipy.stats import zscore

# %%
y=df.iloc[:,-1]
x=df.iloc[:,0:-1]

# %%
y.shape
# Out:
# (13564,)

# %%
x.shape
# Out:
# (13564, 16)

# %%
#dfn=df[age'],df['balance'],df['duration'],df['campaign'],df['pdays'],df['previous']]
z=np.abs(zscore(x))
z
# Out:
#              ID       age       job   marital  education   default   balance  \
# 0      1.211134  0.838114  0.807551  0.276592   0.301053  0.131336  0.402389
# 1      1.362131  3.499987  0.196760  1.914173   1.642982  0.131336  0.463375
# 2      1.461882  0.932421  0.502156  1.360988   1.040875  0.131336  0.393955
# 3      1.132710  1.519549  0.807551  1.360988   1.642982  0.131336  0.784508
# 4      0.783238  0.387871  1.024823  1.914173   0.301053  0.131336  0.669352
# ...         ...       ...       ...       ...        ...       ...       ...
# 13559  0.058563  0.177969  0.108636  0.276592   1.040875  0.131336  0.426069
# 13560  0.843576  1.236630  1.024823  0.276592   1.642982  0.131336  0.299239
# 13561  0.430055  0.555195  0.196760  0.276592   1.642982  0.131336  0.348218
# 13562  1.728467  1.121034  1.330219  1.360988   0.301053  0.131336  0.290155
# 13563  0.933919  1.121034  1.330219  0.276592   0.301053  0.131336  0.440017
#
# ...

# %%
df['default'].unique()
# Out:
# array([0, 1])

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    1,     9,    14, ..., 13550, 13555, 13563], dtype=int64), array([ 1, 14,  6, ..., 12, 13, 14], dtype=int64))

# %%
dfn=df[(z<3).all(axis=1)]
dfn
# Out:
#           ID  age  job  marital  education  default  balance  housing  loan  \
# 0      38441   32    7        1          1        0      118        1     0
# 2       3709   31    6        2          2        0      144        1     0
# 3      37422   57    7        2          0        0     3777        1     0
# 4      12527   45    1        0          1        0     -705        0     1
# 5      16013   32    4        2          2        0        0        1     0
# ...      ...  ...  ...      ...        ...      ...      ...      ...   ...
# 13558  35237   32    9        2          1        0      129        1     0
# 13559  23465   39    4        1          2        0       45        0     0
# 13560  11743   54    1        1          0        0     2281        1     0
# 13561  28292   35    5        1          0        0      285        1     0
# 13562  45163   29    0        2          1        0      464        0     0
#
# ...

# %%
dfn.skew()
# Out:
# ID           0.051465
# age          0.434698
# job          0.249193
# marital     -0.102106
# education    0.193181
# default      0.000000
# balance      2.467216
# housing     -0.213912
# loan         1.888434
# contact      0.728608
# day          0.100284
# month       -0.460334
# duration     1.580973
# campaign     1.966766
# pdays        2.706946
# previous     3.375478
# poutcome    -2.329802
# dtype: float64

# %%
dfn['balance']=np.cbrt(dfn['balance'])

# %%
dfn['pdays']=np.cbrt(dfn['pdays'])

# %%
dfn['previous']=np.cbrt(dfn['previous'])

# %%
dfn.skew()
# Out:
# ID           0.051465
# age          0.434698
# job          0.249193
# marital     -0.102106
# education    0.193181
# default      0.000000
# balance     -0.391348
# housing     -0.213912
# loan         1.888434
# contact      0.728608
# day          0.100284
# month       -0.460334
# duration     1.580973
# campaign     1.966766
# pdays        2.085897
# previous     2.178165
# poutcome    -2.329802
# dtype: float64

# %%
x1=dfn.iloc[:,0:-1]
y1=dfn.iloc[:,-1]

# %%
dfn.plot(kind='box',subplots=True,layout=(3,6),figsize=(10,10))
# Out:
# ID              AxesSubplot(0.125,0.653529;0.110714x0.226471)
# age          AxesSubplot(0.257857,0.653529;0.110714x0.226471)
# job          AxesSubplot(0.390714,0.653529;0.110714x0.226471)
# marital      AxesSubplot(0.523571,0.653529;0.110714x0.226471)
# education    AxesSubplot(0.656429,0.653529;0.110714x0.226471)
# default      AxesSubplot(0.789286,0.653529;0.110714x0.226471)
# balance         AxesSubplot(0.125,0.381765;0.110714x0.226471)
# housing      AxesSubplot(0.257857,0.381765;0.110714x0.226471)
# loan         AxesSubplot(0.390714,0.381765;0.110714x0.226471)
# contact      AxesSubplot(0.523571,0.381765;0.110714x0.226471)
# day          AxesSubplot(0.656429,0.381765;0.110714x0.226471)
# month        AxesSubplot(0.789286,0.381765;0.110714x0.226471)
# duration            AxesSubplot(0.125,0.11;0.110714x0.226471)
# campaign         AxesSubplot(0.257857,0.11;0.110714x0.226471)
# pdays            AxesSubplot(0.390714,0.11;0.110714x0.226471)
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()

# %%
dfn.corr()
# Out:
#                  ID       age       job   marital  education  default  \
# ID         1.000000 -0.024330  0.069524  0.078373   0.099675      NaN
# age       -0.024330  1.000000 -0.026578 -0.403382  -0.116760      NaN
# job        0.069524 -0.026578  1.000000  0.048031   0.153353      NaN
# marital    0.078373 -0.403382  0.048031  1.000000   0.110196      NaN
# education  0.099675 -0.116760  0.153353  0.110196   1.000000      NaN
# default         NaN       NaN       NaN       NaN        NaN      NaN
# balance    0.125889  0.090024  0.018108  0.028087   0.050447      NaN
# housing   -0.185564 -0.171143 -0.124176 -0.013167  -0.084294      NaN
# loan      -0.070663 -0.004247 -0.020899 -0.060554  -0.057368      NaN
# contact   -0.732702  0.030179 -0.090118 -0.037293  -0.115241      NaN
# day       -0.040475 -0.010573  0.020611  0.003659   0.034085      NaN
# month     -0.199233 -0.050207 -0.097150 -0.016126  -0.059920      NaN
# ...

# %%
vif['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x1.columns
vif
# Out:
#     VIF Values   Features
# 0     9.247344         ID
# 1    10.398833        age
# 2     2.819924        job
# 3     4.466673    marital
# 4     3.706707  education
# 5     1.027615    default
# 6     1.232213    balance
# 7     2.482784    housing
# 8     1.200694       loan
# 9     3.396002    contact
# 10    4.510834        day
# 11    5.377042      month
# 12    1.981115   duration
# 13    1.891341   campaign
# 14    1.948949      pdays
# 15    1.546490   previous

# %%
df['poutcome'].value_counts()
# Out:
# 3    11030
# 0     1539
# 1      552
# 2      443
# Name: poutcome, dtype: int64

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE
sm=SMOTE()
trainx,trainy=sm.fit_resample(x,y)
trainy.value_counts()
trainx.value_counts()
# Out:
# ID     age  job  marital  education  default  balance  housing  loan  contact  day  month  duration  campaign  pdays  previous
# 44431  37   8    1        1          0         314     0        0     0        6    1      273       1          182   6           3
# 43652  34   4    1        1          0         551     0        0     0        7    8      347       1          41    5           3
# 34210  37   9    0        1          0         902     1        0     0        4    8      301       2          89    1           3
# 38253  43   3    1        2          0         41      1        0     0        15   8      39        4          328   1           2
# 34980  32   8    2        1          0        -117     1        0     0        6    8      134       1          355   4           2
#                                                                                                                                  ..
# ...

# %%
trainx.shape
# Out:
# (44120, 16)

# %%
trainy.shape
# Out:
# (44120,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [raw]
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score

# %%
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=0.30,random_state=i)
    rfr=RandomForestClassifier()
    rfr.fit(x_train,y_train)
    pred=rfr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print('Best accuracy is',maxaccu ,"at random_state",maxrs)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))

# %%
x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=.30,random_state=66)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %%
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
predgb=gb.predict(x_test)
print(accuracy_score(y_test,predgb))
print(confusion_matrix(y_test,predgb))
print(classification_report(y_test,predgb))
# Out:
# 0.7697189483227561
# [[1972  671  583    0]
#  [ 855 2022  512    0]
#  [ 212  215 2803    0]
#  [   0    0    0 3391]]
#               precision    recall  f1-score   support
#
#            0       0.65      0.61      0.63      3226
#            1       0.70      0.60      0.64      3389
#            2       0.72      0.87      0.79      3230
#            3       1.00      1.00      1.00      3391
#
#     accuracy                           0.77     13236
#    macro avg       0.77      0.77      0.76     13236
# weighted avg       0.77      0.77      0.77     13236

# %%
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
# Out:
# 0.5661831368993654
# [[ 380 1332 1514    0]
#  [ 337 1445 1607    0]
#  [ 126  826 2278    0]
#  [   0    0    0 3391]]
#               precision    recall  f1-score   support
#
#            0       0.45      0.12      0.19      3226
#            1       0.40      0.43      0.41      3389
#            2       0.42      0.71      0.53      3230
#            3       1.00      1.00      1.00      3391
#
#     accuracy                           0.57     13236
#    macro avg       0.57      0.56      0.53     13236
# weighted avg       0.57      0.57      0.54     13236

# %%
etc=ExtraTreesClassifier()
etc.fit(x_train,y_train)
predetc=etc.predict(x_test)
print(accuracy_score(y_test,predetc))
print(confusion_matrix(y_test,predetc))
print(classification_report(y_test,predetc))
# Out:
# 0.9726503475370203
# [[3108   44  127    0]
#  [  79 3203   57    0]
#  [  43   12 3337    0]
#  [   0    0    0 3226]]
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.95      3279
#            1       0.98      0.96      0.97      3339
#            2       0.95      0.98      0.97      3392
#            3       1.00      1.00      1.00      3226
#
#     accuracy                           0.97     13236
#    macro avg       0.97      0.97      0.97     13236
# weighted avg       0.97      0.97      0.97     13236

# %%
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
predrfc=rfc.predict(x_test)
print(accuracy_score(y_test,predrfc))
print(confusion_matrix(y_test,predrfc))
print(classification_report(y_test,predrfc))
# Out:
# 0.9763523723179208
# [[3121   42  116    0]
#  [  56 3224   59    0]
#  [  29   11 3352    0]
#  [   0    0    0 3226]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96      3279
#            1       0.98      0.97      0.97      3339
#            2       0.95      0.99      0.97      3392
#            3       1.00      1.00      1.00      3226
#
#     accuracy                           0.98     13236
#    macro avg       0.98      0.98      0.98     13236
# weighted avg       0.98      0.98      0.98     13236

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.5440465397401028
# [[2316    0  793  117]
#  [2495    0  863   31]
#  [ 635    0 2579   16]
#  [ 838    0  247 2306]]
#               precision    recall  f1-score   support
#
#            0       0.37      0.72      0.49      3226
#            1       0.00      0.00      0.00      3389
#            2       0.58      0.80      0.67      3230
#            3       0.93      0.68      0.79      3391
#
#     accuracy                           0.54     13236
#    macro avg       0.47      0.55      0.49     13236
# weighted avg       0.47      0.54      0.48     13236

# %% [markdown]
# #crossval score

# %%
score=cross_val_score(etc,trainx,trainy)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',accuracy_score(y_test,predetc)-score.mean())
# Out:
# [0.9663418  0.98266092 0.981301   0.98232094 0.97948776]
# 0.9784224841341796
# difference between accuracy score and cross val score is 0.000196433967965981

# %%
score=cross_val_score(rfc,trainx,trainy)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',accuracy_score(y_test,predrfc)-score.mean())
# Out:
# [0.98073436 0.98266092 0.98039438 0.97824116 0.98028105]
# 0.9804623753399818
# difference between accuracy score and cross val score is 0.0014052583862194101

# %%
from sklearn.model_selection import GridSearchCV 
parameters = {"criterion":['gini','entropy'],"random_state":[10,50,1000],"max_depth":[0,10,20],"n_estimators":[50,100,200,300]}
rfc=RandomForestClassifier()
gcv=GridSearchCV(rfc,parameters,cv=5)
gcv.fit(x_train,y_train)
gcv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 20,
#  'n_estimators': 300,
#  'random_state': 50}

# %%
final_model=RandomForestClassifier(criterion='gini',random_state=1000,max_depth=20,n_estimators=100)
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
acc=accuracy_score(y_test,pred)
acc

# %%
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import plot_roc_curve

# %%
plot_roc_curve(final_model,x_test,y_test)
plt.title('roc for the best model')
plt.show()

# %%
y_pred_prob = final_model.predict_proba(x_test)[:,1]
fpr,tpr,thresholds = roc_curve(y_test,y_pred_prob)
roc_auc = auc(fpr,tpr)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='ExtraTreesClassifier(area=%0.2f)'%roc_auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
auc_score= roc_auc_score(y_test,final_model.predict(x_test))
print('Auc score:','/n',auc_score)

# %%
import joblib

# %%
joblib.dump(final_model,'redwine_analysis.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17808\4127448674.py in <module>
# ----> 1 joblib.dump(final_model,'redwine_analysis.pkl')
#
# NameError: name 'final_model' is not defined

# %%
model=joblib.load('redwine_analysis.pkl')
pred=model.predict(x_test)
pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17808\2827936912.py in <module>
# ----> 1 model=joblib.load('redwine_analysis.pkl')
#       2 pred=model.predict(x_test)
#       3 pred
#
# NameError: name 'joblib' is not defined
