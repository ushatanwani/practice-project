# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings ('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats

# %%
df=pd.read_csv("baseball.csv")

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.shape
# Out:
# (30, 17)

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df['W'].nunique()
# Out:
# 24

# %%
df['2B'].nunique()
# Out:
# 22

# %%
df['R'].nunique()
# Out:
# 28

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
sns.boxplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R'>

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
sns.boxplot(df['ERA'])
# Out:
# <AxesSubplot:xlabel='ERA'>

# %%
sns.distplot(df,bins=10)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.histplot(df)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='R',y='SO',hue='SV',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='SO'>

# %%
sns.scatterplot(x='AB',y='2B',hue="E",data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='2B'>

# %%
df.plot(kind='box',subplots=True,layout=(4,5),figsize=(10,10))
# Out:
# W         AxesSubplot(0.125,0.712609;0.133621x0.167391)
# R      AxesSubplot(0.285345,0.712609;0.133621x0.167391)
# AB      AxesSubplot(0.44569,0.712609;0.133621x0.167391)
# H      AxesSubplot(0.606034,0.712609;0.133621x0.167391)
# 2B     AxesSubplot(0.766379,0.712609;0.133621x0.167391)
# 3B        AxesSubplot(0.125,0.511739;0.133621x0.167391)
# HR     AxesSubplot(0.285345,0.511739;0.133621x0.167391)
# BB      AxesSubplot(0.44569,0.511739;0.133621x0.167391)
# SO     AxesSubplot(0.606034,0.511739;0.133621x0.167391)
# SB     AxesSubplot(0.766379,0.511739;0.133621x0.167391)
# RA         AxesSubplot(0.125,0.31087;0.133621x0.167391)
# ER      AxesSubplot(0.285345,0.31087;0.133621x0.167391)
# ERA      AxesSubplot(0.44569,0.31087;0.133621x0.167391)
# CG      AxesSubplot(0.606034,0.31087;0.133621x0.167391)
# SHO     AxesSubplot(0.766379,0.31087;0.133621x0.167391)
# SV            AxesSubplot(0.125,0.11;0.133621x0.167391)
# E          AxesSubplot(0.285345,0.11;0.133621x0.167391)
# ...

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
x=df.iloc[:,1:]
y=df.iloc[:,0]

# %%
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
y.head()
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# 4    74
# Name: W, dtype: int64

# %%
x.head()
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101
# 4   86

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#       VIF Values Features
# 0    1638.985029        R
# 1    4277.157018       AB
# 2    4698.798408        H
# 3     904.439835       2B
# 4      32.435486       3B
# 5     285.773237       HR
# 6     269.485018       BB
# 7     398.234104       SO
# 8      28.654970       SB
# 9   17204.829356       RA
# 10  49837.289228       ER
# 11  23551.544014      ERA
# 12      6.771036       CG
# 13     30.276598      SHO
# 14    119.686080       SV
# 15     94.215202        E

# %%
df.drop(["ER"],axis=1,inplace=True)

# %%
y.value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: W, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_lr=lr.predict(x_test)
    acc=r2_score(y_test,pred_lr)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print("maximum r2 score is",maxaccu,"on random state",maxrs)
# Out:
# maximum r2 score is 0.9172122929401271 on random state 114

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as kNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor 
from sklearn.svm import SVR

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
pred_train=lr.predict(x_train)
print('r2_score:',r2_score(y_test,pred_lr))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_lr))
print('mean squared error:',mean_squared_error(y_test,pred_lr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# r2_score: -0.4712529705727888
# r2_score on training data: 99.71706766246132
# mean_absolute_error: 9.776004186395678
# mean squared error: 218.72627495848792
# root mean squared error: 14.789397383209632

# %%
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
pred_dtc=dtc.predict(x_test)
pred_train=dtc.predict(x_train)
print('r2_score:',r2_score(y_test,pred_dtc))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_dtc))
print('mean squared error:',mean_squared_error(y_test,pred_dtc))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_dtc)))
# Out:
# r2_score: -0.041853512705530616
# r2_score on training data: 100.0
# mean_absolute_error: 10.222222222222221
# mean squared error: 154.88888888888889
# root mean squared error: 12.445436468396313

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print('r2_score:',r2_score(y_test,pred_knn))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_knn))
print('mean squared error:',mean_squared_error(y_test,pred_knn))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# r2_score: 0.2149177877428996
# r2_score on training data: 64.83383586426183
# mean_absolute_error: 9.044444444444444
# mean squared error: 116.71555555555558
# root mean squared error: 10.80349737610722

# %%
ls=Lasso()
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
pred_train=ls.predict(x_train)
print('r2_score:',r2_score(y_test,pred_ls))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ls))
print('mean squared error:',mean_squared_error(y_test,pred_ls))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# r2_score: 0.5053832426421085
# r2_score on training data: 96.41433086188471
# mean_absolute_error: 6.876850097992084
# mean squared error: 73.5330245938732
# root mean squared error: 8.575139916868599

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print('r2_score:',r2_score(y_test,pred_rd))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_rd))
print('mean squared error:',mean_squared_error(y_test,pred_rd))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# r2_score: 0.4813768706688266
# r2_score on training data: 97.95371219272305
# mean_absolute_error: 6.094569317644439
# mean squared error: 77.10197189390111
# root mean squared error: 8.780772852881523

# %%
ad=AdaBoostRegressor()
ad.fit(x_train,y_train)
pred_ad=ad.predict(x_test)
pred_train=ad.predict(x_train)
print('r2_score:',r2_score(y_test,pred_ad))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ad))
print('mean squared error:',mean_squared_error(y_test,pred_ad))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_ad)))
# Out:
# r2_score: 0.5842656950672647
# r2_score on training data: 98.91862196882481
# mean_absolute_error: 6.894444444444444
# mean squared error: 61.805833333333325
# root mean squared error: 7.861668609991986

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr=gbr.predict(x_test)
pred_train=gbr.predict(x_train)
print('r2_score:',r2_score(y_test,pred_gbr))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_gbr))
print('mean squared error:',mean_squared_error(y_test,pred_gbr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# r2_score: 0.32119391895467786
# r2_score on training data: 99.9999802654776
# mean_absolute_error: 8.602566832448488
# mean squared error: 100.91583738207123
# root mean squared error: 10.045687501712923

# %%
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('r2_score:',r2_score(y_test,pred_svr))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_svr))
print('mean squared error:',mean_squared_error(y_test,pred_svr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# r2_score: -0.05020122390415449
# r2_score on training data: -1.1807923911870244
# mean_absolute_error: 10.448612840622467
# mean squared error: 156.12991528708432
# root mean squared error: 12.495195688226907

# %%
#checking crossval score

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lr,x_train,y_train)
print(score)
print(score.mean())
print('difference between r2 score and cross val score is',r2_score(y_test,pred_lr)-score.mean())
# Out:
# [-6.89955736 -1.22701674  0.84915269 -0.24090463  0.78299878]
# -1.347065454299249
# difference between r2 score and cross val score is 0.8758124837264603

# %%
score=cross_val_score(ad,x_train,y_train)
print(score)
print(score.mean())
print('difference between r2 score and cross val score is',r2_score(y_test,pred_ad)-score.mean())
# Out:
# [ 0.58100858 -0.12157998  0.62750879 -2.38996682  0.24271335]
# -0.21206321584377638
# difference between r2 score and cross val score is 0.7963289109110411

# %%
from sklearn.model_selection import GridSearchCV 
parameters = {"learning_rate":[0.00001,0.0001,0.001,1.0,1.1],"random_state":[10,50,200],"n_estimators":[50,100,200,300]}
ad=AdaBoostRegressor()
acv=GridSearchCV(ad,parameters,cv=5)
acv.fit(x_train,y_train)
acv.best_params_
# Out:
# {'learning_rate': 1e-05, 'n_estimators': 50, 'random_state': 50}
