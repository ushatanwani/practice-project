# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings ('ignore')
import seaborn as sns
import matplotlib.pyplot as plt
#import scikitlearn as scipy
from scipy import stats

# %%
df=pd.read_csv("medical.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
import sklearn
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

df["region"]=le.fit_transform(df['region'])

# %%
df['region'].unique()
# Out:
# array([3, 2, 1, 0])

# %%
df.shape
# Out:
# (1338, 7)

# %%
import sklearn
from sklearn import preprocessing
le=preprocessing.LabelEncoder()

df["sex"]=le.fit_transform(df['sex'])

df['smoker']=le.fit_transform(df['smoker'])

# %%
df['sex'].unique()
# Out:
# array([0, 1])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region       charges
# count  1338.000000   1338.000000
# mean      1.515695  13270.422265
# std       1.104885  12110.011237
# min       0.000000   1121.873900
# 25%       1.000000   4740.287150
# 50%       2.000000   9382.033000
# 75%       2.000000  16639.912515
# max       3.000000  63770.428010

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.038101
# charges     1.515880
# dtype: float64

# %%
x=df.iloc[:,0:6]
y=df['charges']

# %%
x.head()
# Out:
#    age  sex     bmi  children  smoker  region
# 0   19    0  27.900         0       1       3
# 1   18    1  33.770         1       0       2
# 2   28    1  33.000         3       0       2
# 3   33    1  22.705         0       0       1
# 4   32    1  28.880         0       0       1

# %%
x.describe()
# Out:
#                age          sex          bmi     children       smoker  \
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025     0.505232    30.663397     1.094918     0.204783
# std      14.049960     0.500160     6.098187     1.205493     0.403694
# min      18.000000     0.000000    15.960000     0.000000     0.000000
# 25%      27.000000     0.000000    26.296250     0.000000     0.000000
# 50%      39.000000     1.000000    30.400000     1.000000     0.000000
# 75%      51.000000     1.000000    34.693750     2.000000     0.000000
# max      64.000000     1.000000    53.130000     5.000000     1.000000
#
#             region
# count  1338.000000
# mean      1.515695
# std       1.104885
# min       0.000000
# 25%       1.000000
# 50%       2.000000
# 75%       2.000000
# max       3.000000

# %%
from scipy.stats import zscore

# %%
sns.boxplot(df['bmi'])
# Out:
# <AxesSubplot:xlabel='bmi'>

# %%
sns.distplot(df['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Density'>

# %%
sns.distplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.boxplot(df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df.corr()
# Out:
#                age       sex       bmi  children    smoker    region   charges
# age       1.000000 -0.020856  0.109272  0.042469 -0.025019  0.002127  0.299008
# sex      -0.020856  1.000000  0.046371  0.017163  0.076185  0.004588  0.057292
# bmi       0.109272  0.046371  1.000000  0.012759  0.003750  0.157566  0.198341
# children  0.042469  0.017163  0.012759  1.000000  0.007673  0.016569  0.067998
# smoker   -0.025019  0.076185  0.003750  0.007673  1.000000 -0.002181  0.787251
# region    0.002127  0.004588  0.157566  0.016569 -0.002181  1.000000 -0.006208
# charges   0.299008  0.057292  0.198341  0.067998  0.787251 -0.006208  1.000000

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x="charges",y="region",hue='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='charges', ylabel='region'>

# %%
sns.scatterplot(x="charges",y="bmi",hue='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='charges', ylabel='bmi'>

# %%
sns.scatterplot(x="charges",y="bmi",hue='age',data=df)
# Out:
# <AxesSubplot:xlabel='charges', ylabel='bmi'>

# %%
sns.scatterplot(x="charges",y="age",hue='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='charges', ylabel='age'>

# %%
sns.scatterplot(x="age",y="bmi",hue='smoker',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='bmi'>

# %%
sns.scatterplot(x='bmi',y='charges',hue='sex',data=df)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %%
df.skew()
# Out:
# age         0.055673
# sex        -0.020951
# bmi         0.284047
# children    0.938380
# smoker      1.464766
# region     -0.038101
# charges     1.515880
# dtype: float64

# %%
df.plot(kind='box',subplots=True,layout=(2,6),figsize=(10,10))
# Out:
# age            AxesSubplot(0.125,0.53;0.110714x0.35)
# sex         AxesSubplot(0.257857,0.53;0.110714x0.35)
# bmi         AxesSubplot(0.390714,0.53;0.110714x0.35)
# children    AxesSubplot(0.523571,0.53;0.110714x0.35)
# smoker      AxesSubplot(0.656429,0.53;0.110714x0.35)
# region      AxesSubplot(0.789286,0.53;0.110714x0.35)
# charges        AxesSubplot(0.125,0.11;0.110714x0.35)
# dtype: object

# %%
from scipy.stats import zscore
z=np.abs(zscore(df['bmi']))
z
# Out:
# 0       0.453320
# 1       0.509621
# 2       0.383307
# 3       1.305531
# 4       0.292556
#           ...
# 1333    0.050297
# 1334    0.206139
# 1335    1.014878
# 1336    0.797813
# 1337    0.261388
# Name: bmi, Length: 1338, dtype: float64

# %%
threshold=3
np.where(z>3)
# Out:
# (array([ 116,  847, 1047, 1317], dtype=int64),)

# %%
df.drop([ 116,  847, 1047, 1317],axis=0,inplace=True)

# %%
df.shape
# Out:
# (1334, 7)

# %%
#VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF Values  Features
# 0    7.551348       age
# 1    2.001061       sex
# 2   10.371829       bmi
# 3    1.801245  children
# 4    1.256837    smoker
# 5    2.924528    region

# %%
y=df['charges']
x=df.iloc[:,0:6]

# %%
x.shape
# Out:
# (1334, 6)

# %%
x.head()
# Out:
#    age  sex     bmi  children  smoker  region
# 0   19    0  27.900         0       1       3
# 1   18    1  33.770         1       0       2
# 2   28    1  33.000         3       0       2
# 3   33    1  22.705         0       0       1
# 4   32    1  28.880         0       0       1

# %%
#Modeling

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#            age       sex       bmi  children    smoker    region
# 0    -1.442249 -1.007525 -0.450359 -0.909299  1.971407  1.343594
# 1    -1.513528  0.992532  0.528191 -0.080177 -0.507252  0.439278
# 2    -0.800739  0.992532  0.399829  1.578066 -0.507252  0.439278
# 3    -0.444344  0.992532 -1.316383 -0.909299 -0.507252 -0.465038
# 4    -0.515623  0.992532 -0.286989 -0.909299 -0.507252 -0.465038
# ...        ...       ...       ...       ...       ...       ...
# 1329  0.767397  0.992532  0.061421  1.578066 -0.507252 -0.465038
# 1330 -1.513528 -1.007525  0.219789 -0.909299 -0.507252 -1.369355
# 1331 -1.513528 -1.007525  1.041637 -0.909299 -0.507252  0.439278
# 1332 -1.299692 -1.007525 -0.800436 -0.909299 -0.507252  1.343594
# 1333  1.551465 -1.007525 -0.255316 -0.909299  1.971407 -0.465038
#
# [1334 rows x 6 columns]

# %% [markdown]
# #Modelling

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.linear_model import LinearRegression

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=30,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_lr=lr.predict(x_test)
    acc=r2_score(y_test,pred_lr)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print("maximum r2 score is",maxaccu,"on random state",maxrs)
# Out:
# maximum r2 score is 0.9244728769699161 on random state 16

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as kNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor 
from sklearn.svm import SVR

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
pred_train=lr.predict(x_train)
print('r2_score:',r2_score(y_test,pred_lr))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_lr))
print('mean squared error:',mean_squared_error(y_test,pred_lr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# r2_score: 0.7253634865118318
# r2_score on training data: 75.074911259563
# mean_absolute_error: 3933.2347578865038
# mean squared error: 27662394.20888361
# root mean squared error: 5259.505129656554

# %%
dtc=DecisionTreeRegressor()
dtc.fit(x_train,y_train)
pred_dtc=dtc.predict(x_test)
pred_train=dtc.predict(x_train)
print('r2_score:',r2_score(y_test,pred_dtc))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_dtc))
print('mean squared error:',mean_squared_error(y_test,pred_dtc))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_dtc)))
# Out:
# r2_score: 0.2639037386906601
# r2_score on training data: 99.86362254648695
# mean_absolute_error: 4244.3863040000015
# mean squared error: 74142307.94515821
# root mean squared error: 8610.59277548057

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN
knn=KNN()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
pred_train=knn.predict(x_train)
print('r2_score:',r2_score(y_test,pred_knn))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_knn))
print('mean squared error:',mean_squared_error(y_test,pred_knn))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# r2_score: 0.7980814588026512
# r2_score on training data: 87.64655609744045
# mean_absolute_error: 3102.647877666666
# mean squared error: 20337974.05065151
# root mean squared error: 4509.764301008591

# %%
ls=Lasso()
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
pred_train=ls.predict(x_train)
print('r2_score:',r2_score(y_test,pred_ls))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ls))
print('mean squared error:',mean_squared_error(y_test,pred_ls))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_ls)))
# Out:
# r2_score: 0.7254448756463949
# r2_score on training data: 75.07490695027897
# mean_absolute_error: 3932.0542101380343
# mean squared error: 27654196.397543777
# root mean squared error: 5258.725738954617

# %%
rd=Ridge()
rd.fit(x_train,y_train)
pred_rd=rd.predict(x_test)
pred_train=rd.predict(x_train)
print('r2_score:',r2_score(y_test,pred_rd))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_rd))
print('mean squared error:',mean_squared_error(y_test,pred_rd))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# r2_score: 0.7254612303431289
# r2_score on training data: 75.07486733703695
# mean_absolute_error: 3932.279804021993
# mean squared error: 27652549.09266623
# root mean squared error: 5258.569110762569

# %%
ad=AdaBoostRegressor()
ad.fit(x_train,y_train)
pred_ad=ad.predict(x_test)
pred_train=ad.predict(x_train)
print('r2_score:',r2_score(y_test,pred_ad))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ad))
print('mean squared error:',mean_squared_error(y_test,pred_ad))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_ad)))
# Out:
# r2_score: 0.8096291804404382
# r2_score on training data: 82.53028880776473
# mean_absolute_error: 3804.4977555001356
# mean squared error: 19174845.287830688
# root mean squared error: 4378.909143591665

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr=gbr.predict(x_test)
pred_train=gbr.predict(x_train)
print('r2_score:',r2_score(y_test,pred_gbr))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_gbr))
print('mean squared error:',mean_squared_error(y_test,pred_gbr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# r2_score: 0.8579438663696326
# r2_score on training data: 89.96566409569681
# mean_absolute_error: 2430.1290638432924
# mean squared error: 14308413.394719154
# root mean squared error: 3782.6463480900716

# %%
svc=SVR()
svc.fit(x_train,y_train)
pred_svc=svc.predict(x_test)
pred_train=svc.predict(x_train)
print('r2_score:',r2_score(y_test,pred_svc))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_svc))
print('mean squared error:',mean_squared_error(y_test,pred_svc))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_svc)))
# Out:
# r2_score: -0.012521646494559002
# r2_score on training data: -9.85007284216195
# mean_absolute_error: 6770.854239851789
# mean squared error: 101984883.8547357
# root mean squared error: 10098.75654992909

# %% [markdown]
# #Checking cross val score

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(lr,x_train,y_train)
print(score)
print(score.mean())
print('difference between r2 score and cross val score is',r2_score(y_test,pred_lr)-score.mean())
# Out:
# [0.76279367 0.72236284 0.78456895 0.72597549 0.73072803]
# 0.7452857966386649
# difference between r2 score and cross val score is -0.019922310126833098

# %%
score=cross_val_score(lr,x_train,y_train)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',r2_score(y_test,pred_lr)-score.mean())
# Out:
# [0.76279367 0.72236284 0.78456895 0.72597549 0.73072803]
# 0.7452857966386649
# difference between accuracy score and cross val score is -0.019922310126833098

# %%
score=cross_val_score(gbr,x_train,y_train)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',r2_score(y_test,pred_gbr)-score.mean())
# Out:
# [0.87376618 0.7931199  0.89071551 0.87391355 0.83593833]
# 0.8534906948908901
# difference between accuracy score and cross val score is 0.002190089935612538

# %%
from sklearn.model_selection import GridSearchCV 
parameters = {"loss":['squared_error', 'absolute_error', 'huber', 'quantile'],"criterion":['friedman_mse', 'squared_error'],"random_state":[10,50,200],"max_depth":[0,10,20],"n_estimators":[50,100,200,300]}
gbr=GradientBoostingRegressor()
gcv=GridSearchCV(gbr,parameters,cv=5)
gcv.fit(x_train,y_train)
gcv.best_params_

# %%
final_model=GradientBoostingRegressor()
final_model.fit(x_train,y_train)
pred_gbr=final_model.predict(x_test)
pred_train=final_model.predict(x_train)
print('r2_score:',r2_score(y_test,pred_gbr))
print('r2_score on training data:',r2_score(y_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y_test,pred_gbr))
print('mean squared error:',mean_squared_error(y_test,pred_gbr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_gbr)))
# Out:
# r2_score: 0.860100325873523
# r2_score on training data: 89.96566409569681
# mean_absolute_error: 2389.897901811453
# mean squared error: 14091206.905551132
# root mean squared error: 3753.8256360080354

# %%
import joblib
joblib.dump(final_model,'medical.pkl')
# Out:
# ['medical.pkl']

# %%
loaded_model=joblib.load("medical.pkl")

# %%
loaded_model=joblib.load("medical.pkl")
