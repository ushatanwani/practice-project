# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings ('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("avocado.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# ...

# %%
df['region'].value_counts()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# ...

# %%
df['region'].nunique()
# Out:
# 54

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.shape
# Out:
# (18249, 14)

# %%
df['Date']=pd.to_datetime(df.Date,format = '%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df['XLarge Bags'].nunique()
# Out:
# 5588

# %%
df['type'].nunique()
# Out:
# 2

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# ...

# %%
print("total duplicate rows",df.duplicated().sum())
# Out:
# total duplicate rows 0

# %%
sns.lmplot(x="Total Volume",y="AveragePrice",data=df)
plt.show()

# %%
sns.scatterplot(x="Total Volume",y=4046,data=df)
plt.show()

# %%
sns.lmplot(x="AveragePrice",y="Total Bags",data=df)

# %%
plt.figure(figsize=(10,16))
p=1
for i in df:
    if p<=14:
        plt.subplot(5,4,p)
        sns.scatterplot(x="AveragePrice",y=i,data=df,color="Blue")
        plt.xlabel("Averageprice")
        plt.ylabel(i)
    p+=1
plt.show()

# %%
#high positive corelation between Averageprice and Totalvolume

# %%
sns.pairplot(data=df)

# %%
plt.figure(figsize=(10,15))
plt.plot(df.AveragePrice,label="yearly total volume")
plt.ylabel("Total Volume")
plt.xlabel("year")
plt.title("yearly Total Volume")
plt.show()

# %%
df['type'].nunique()
# Out:
# 2

# %%
df['year'].nunique()
# Out:
# 4

# %%
sns.countplot(df['year'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
plt.figure(figsize=(10,15))
sns.pointplot(x='AveragePrice',y='region',data=df,hue='year')
plt.ylabel('Region')
plt.xlabel('AveragePrice')
plt.title("Yearly average price in different region")
plt.show()

# %%
#Region Vs AveragePrice

# %%
plt.figure(figsize=(10,15))
sns.pointplot(x='AveragePrice',y='region',hue='type',data=df)
plt.xlabel("Averageprice")
plt.ylabel("region")
plt.show()

# %%
df.plot(kind='box',subplots=True,layout=(5,6),figsize=(10,10))
plt.show()

# %%
# classifying Type of Avocado

# %%
import sklearn
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
list=['type','region']
df[list]=df[list].apply(le.fit_transform)

# %%
y=df['region']
y.shape
# Out:
# (18249,)

# %%
y=df['region']
x=df.drop(['Date','region'],axis=1)
x
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year
# ...

# %%
x.shape
# Out:
# (18249, 11)

# %%
y.shape
# Out:
# (18249,)

# %%
x.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# type             0.000329
# year             0.215339
# dtype: float64

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0          0.188689      0.227716  0.230816  0.199902  0.212091    0.234170
# 1          0.139020      0.230427  0.231103  0.208054  0.211997    0.233350
# 2          1.182069      0.212085  0.231007  0.154478  0.211325    0.234730
# 3          0.809551      0.223444  0.230741  0.185350  0.211864    0.237096
# 4          0.312861      0.231538  0.230891  0.208719  0.211834    0.236718
# ...             ...           ...       ...       ...       ...         ...
# 18244      0.556347      0.241373  0.230017  0.243857  0.212540    0.229301
# 18245      0.755023      0.242296  0.230693  0.242277  0.212540    0.233594
# 18246      1.152375      0.242331  0.230693  0.243090  0.205766    0.233463
# 18247      1.301382      0.241625  0.230428  0.242651  0.205774    0.231866
# 18248      0.531512      0.241253  0.229347  0.243170  0.210450    0.230807
#
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([  346,   359,   780, ..., 17304, 17402, 17428], dtype=int64), array([2, 2, 8, ..., 0, 0, 0], dtype=int64))

# %%
dfn=df[(z<3).all(axis=1)]

# %%
dfn
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %%
y=dfn['region']

# %%
y.shape
# Out:
# (17651,)

# %%
x=dfn.iloc[:,1:12]

# %%
x.shape
# Out:
# (17651, 11)

# %%
x.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    1.240435
# 4046            1.555876
# 4225            1.277025
# 4770            1.635614
# Total Bags      1.231831
# Small Bags      1.246033
# Large Bags      1.276213
# XLarge Bags     2.277028
# type           -0.037741
# year            0.229976
# dtype: float64

# %%
x['Total Volume']=np.cbrt(x['Total Volume'])

# %%
x['4770']=np.cbrt(x['4770'])

# %%
x['XLarge Bags']=np.cbrt(x['XLarge Bags'])

# %%
x['Total Bags']=np.cbrt(x['Total Bags'])

# %%
x['Small Bags']=np.cbrt(x['Small Bags'])

# %%
x['Large Bags']=np.cbrt(x['Large Bags'])

# %%
x['4225']=np.cbrt(x['4225'])

# %%
x['4046']=np.cbrt(x['4046'])

# %%
x.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    0.340102
# 4046            0.083828
# 4225            0.002759
# 4770           -0.102949
# Total Bags      0.141323
# Small Bags     -0.290344
# Large Bags     -0.665466
# XLarge Bags     1.036551
# type           -0.037741
# year            0.229976
# dtype: float64

# %%
df['XLarge Bags'].nunique()
# Out:
# 5588

# %%
x.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.573702 -0.553078 -0.451679 -0.475516
# Total Volume     -0.573702      1.000000  0.887899  0.924892  0.812903
# 4046             -0.553078      0.887899  1.000000  0.756386  0.728608
# 4225             -0.451679      0.924892  0.756386  1.000000  0.792031
# 4770             -0.475516      0.812903  0.728608  0.792031  1.000000
# Total Bags       -0.558064      0.944751  0.804207  0.825881  0.757871
# Small Bags       -0.480203      0.891010  0.760668  0.768792  0.729032
# Large Bags       -0.460407      0.643586  0.563658  0.581964  0.521745
# XLarge Bags      -0.381831      0.650737  0.583765  0.591797  0.609934
# type              0.613150     -0.789181 -0.714625 -0.742767 -0.769015
# year              0.091704      0.067118 -0.000803 -0.002876 -0.049268
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      type  \
# ...

# %%
sns.heatmap(x.corr())
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0         -0.195352     -0.179235 -0.666994  0.324844 -0.042483   -0.566364
# 1         -0.143510     -0.248376 -0.767937  0.241952 -0.015166   -0.528893
# 2         -1.232207      0.100289 -0.729948  0.629663  0.106229   -0.593739
# 3         -0.843387     -0.086594 -0.645767  0.444313  0.016718   -0.731708
# 4         -0.324959     -0.279800 -0.690031  0.234497  0.023104   -0.706690
# ...             ...           ...       ...       ...       ...         ...
# 17646      0.582289     -0.724912 -0.497188 -0.918499 -1.312143   -0.377429
# 17647      0.789660     -0.802981 -0.633260 -0.678753 -1.312143   -0.539741
# 17648      1.204402     -0.806257 -0.633215 -0.780970  0.404709   -0.533885
# 17649      1.359930     -0.744837 -0.571810 -0.722058  0.404465   -0.467742
# 17650      0.556367     -0.715726 -0.405622 -0.792956  0.194377   -0.428401
#
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()

# %%
vif['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['Features']=x.columns
vif
# Out:
#     VIF Values      Features
# 0     2.067762  AveragePrice
# 1    59.231275  Total Volume
# 2     6.982929          4046
# 3    12.759781          4225
# 4     3.761591          4770
# 5    29.666494    Total Bags
# 6    11.531554    Small Bags
# 7     2.699735    Large Bags
# 8     2.019649   XLarge Bags
# 9     3.914372          type
# 10    1.427588          year

# %%
y.value_counts()
# Out:
# 0     338
# 16    338
# 49    338
# 44    338
# 39    338
# 38    338
# 35    338
# 34    338
# 32    338
# 30    338
# 26    338
# 23    338
# 19    338
# 18    338
# 27    338
# 8     338
# 2     338
# 13    338
# 12    338
# 11    338
# 4     338
# 5     338
# 10    338
# 9     338
# 20    337
# 1     337
# 28    337
# 33    336
# 41    336
# 40    336
# 14    336
# 50    336
# 31    335
# 24    335
# 25    333
# 48    333
# 21    333
# 53    332
# 7     332
# 22    331
# 17    331
# 36    330
# 3     329
# 37    328
# 47    328
# 43    326
# 29    325
# 46    307
# 42    301
# 45    292
# 6     290
# 15    272
# 52    256
# 51    169
# Name: region, dtype: int64

# %%
from imblearn import under_sampling, over_sampling
from imblearn.over_sampling import SMOTE

sm=SMOTE()
trainx,trainy=sm.fit_resample(x,y)
trainy.value_counts()
trainx.value_counts()
# Out:
# AveragePrice  Total Volume  4046       4225       4770       Total Bags  Small Bags  Large Bags  XLarge Bags  type      year
# -2.502354     -0.180475     -1.005688  -0.576143  -1.312143   0.329045   -1.202561    1.060018   -0.659564    0.981309   0.917166    1
#  0.400839     -0.413335     -0.103791  -0.052294  -0.226269  -0.617363   -2.094115    0.441063   -0.659564    0.981309  -1.210013    1
#               -0.173545     -0.383953  -0.081373   0.082713   0.157201   -0.030298    0.770654   -0.659564    0.981309   0.917166    1
#               -0.176205     -0.232568  -0.100222   0.839973   0.065627    0.084355    0.545512   -0.659564    0.981309   0.917166    1
#               -0.223720     -0.046105   0.013905   0.742963  -0.221256   -0.052265    0.081026   -0.659564    0.981309  -1.210013    1
#                                                                                                                                     ..
# ...

# %%
trainx.shape
# Out:
# (18252, 11)

# %%
trainy.shape
# Out:
# (18252,)

# %%
#classifying type of avocado

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=0.30,random_state=i)
    rfr=RandomForestClassifier()
    rfr.fit(x_train,y_train)
    pred=rfr.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
        
print('Best accuracy is',maxaccu ,"at random_state",maxrs)
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# Best accuracy is 0.9139883126369612 at random_state 127
# [[105   0   0 ...   0   0   0]
#  [  0  81   0 ...   0   0   0]
#  [  0   0  94 ...   0   0   0]
#  ...
#  [  0   0   0 ... 104   0   0]
#  [  0   0   0 ...   1  91   0]
#  [  0   0   0 ...   0   0  82]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       114
#            1       0.88      0.87      0.88        93
#            2       0.99      0.93      0.96       101
#            3       0.87      0.87      0.87        99
#            4       0.93      0.97      0.95        97
#            5       0.84      0.77      0.80       103
#            6       0.98      1.00      0.99       105
#            7       0.95      0.95      0.95       101
#            8       0.98      0.99      0.99       104
#            9       0.94      0.88      0.91       111
#           10       0.79      0.87      0.83        97
#           11       0.93      0.94      0.93       110
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=.30,random_state=maxrs)
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # ad=AdaBoostClassifier()
# ad.fit(x_train,y_train)
# predad=ad.predict(x_test)
# print(accuracy_score(y_test,predad))
# print(confusion_matrix(y_test,predad))
# print(classification_report(y_test,predad))

# %%
etc=ExtraTreesClassifier()
etc.fit(x_train,y_train)
predetc=etc.predict(x_test)
print(accuracy_score(y_test,predetc))
print(confusion_matrix(y_test,predetc))
print(classification_report(y_test,predetc))
# Out:
# 0.920927684441198
# [[ 97   0   0 ...   0   0   0]
#  [  0  76   0 ...   0   0   0]
#  [  0   0  98 ...   0   0   0]
#  ...
#  [  0   0   0 ... 109   0   0]
#  [  0   0   0 ...   1 113   0]
#  [  0   2   0 ...   0   0  93]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.91       105
#            1       0.78      0.84      0.81        90
#            2       0.98      1.00      0.99        98
#            3       0.91      0.91      0.91       100
#            4       0.94      0.97      0.95        86
#            5       0.94      0.83      0.88        98
#            6       0.97      1.00      0.98        97
#            7       0.85      0.95      0.90       101
#            8       0.97      0.98      0.98       105
#            9       0.88      0.96      0.92        99
#           10       0.85      0.89      0.87       102
#           11       0.91      0.97      0.94       102
# ...

# %%
from sklearn.svm import SVC

svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.8088020452885317
# [[ 90   0   0 ...   0   0   0]
#  [  0  58   0 ...   0   0   0]
#  [  0   0  93 ...   0   0   0]
#  ...
#  [  0   0   0 ... 109   0   0]
#  [  0   0   0 ...   1 113   0]
#  [  0   3   2 ...   0   0  73]]
#               precision    recall  f1-score   support
#
#            0       0.74      0.86      0.80       105
#            1       0.48      0.64      0.55        90
#            2       0.95      0.95      0.95        98
#            3       0.76      0.78      0.77       100
#            4       0.84      0.88      0.86        86
#            5       0.86      0.68      0.76        98
#            6       1.00      0.99      0.99        97
#            7       0.82      0.79      0.81       101
#            8       0.96      0.93      0.95       105
#            9       0.71      0.88      0.78        99
#           10       0.60      0.78      0.68       102
#           11       0.82      0.91      0.86       102
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier as KNN
knn=KNN()
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
print(accuracy_score(y_test,predknn))
print(confusion_matrix(y_test,predknn))
print(classification_report(y_test,predknn))
# Out:
# 0.8349159970781592
# [[ 94   0   0 ...   0   0   0]
#  [  0  73   0 ...   0   0   0]
#  [  0   0  91 ...   0   0   0]
#  ...
#  [  0   0   0 ... 109   0   0]
#  [  0   0   0 ...   0 109   0]
#  [  0   2   0 ...   0   0  86]]
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83       105
#            1       0.60      0.81      0.69        90
#            2       0.93      0.93      0.93        98
#            3       0.86      0.83      0.85       100
#            4       0.84      0.92      0.88        86
#            5       0.75      0.68      0.72        98
#            6       0.91      0.93      0.92        97
#            7       0.84      0.86      0.85       101
#            8       0.97      0.90      0.93       105
#            9       0.69      0.85      0.76        99
#           10       0.64      0.75      0.69       102
#           11       0.84      0.92      0.88       102
# ...

# %%
gbc=GradientBoostingClassifier()
gbc.fit(x_train,y_train)
predgbc=gbc.predict(x_test)
print(accuracy_score(y_test,predgbc))
print(confusion_matrix(y_test,predgbc))
print(classification_report(y_test,predgbc))
# Out:
# 0.8392987582176772
# [[ 86   0   0 ...   0   0   0]
#  [  0  62   0 ...   0   0   1]
#  [  0   0  89 ...   0   0   0]
#  ...
#  [  0   0   0 ... 107   2   0]
#  [  0   0   0 ...   1 110   0]
#  [  0   1   0 ...   0   0  84]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83       105
#            1       0.70      0.69      0.69        90
#            2       0.94      0.91      0.92        98
#            3       0.79      0.77      0.78       100
#            4       0.82      0.86      0.84        86
#            5       0.77      0.77      0.77        98
#            6       0.99      0.97      0.98        97
#            7       0.86      0.88      0.87       101
#            8       0.97      0.88      0.92       105
#            9       0.84      0.89      0.86        99
#           10       0.70      0.83      0.76       102
#           11       0.82      0.86      0.84       102
# ...

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(etc,x_train,y_train)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',accuracy_score(y_test,predetc)-score.mean())
# Out:
# [0.90336463 0.90254403 0.90802348 0.90958904 0.90880626]
# 0.9064654900483571
# difference between accuracy score and cross val score is 0.01446219439284091

# %%
from sklearn.model_selection import GridSearchCV 
parameters = {"criterion":['gini','entropy'],"random_state":[10,50,1000],"max_depth":[5,10,20],"n_estimators":[50,100,200,300]}
etc=ExtraTreesClassifier()
gcv=GridSearchCV(etc,parameters,cv=5)
gcv.fit(x_train,y_train)
gcv.best_params_

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3500\1122075600.py in <module>
#       3 etc=ExtraTreesClassifier()
#       4 gcv=GridSearchCV(etc,parameters,cv=5)
# ----> 5 gcv.fit(x_train,y_train)
#       6 gcv.best_params_
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# -> 1392         evaluate_candidates(ParameterGrid(self.param_grid))
#    1393
# ...

# %%
final_model=ExtraTreesClassifier(criterion='entropy',max_depth = 20, n_estimators =300, random_state = 10)
final_model.fit(x_train,y_train)
predetc=final_model.predict(x_test)
pred_train=final_model.predict(x_train)
print(accuracy_score(y_test,predetc))
print(confusion_matrix(y_test,predetc))
print(classification_report(y_test,predetc))
# Out:
# 0.9251278305332359
# [[ 98   0   0 ...   0   0   0]
#  [  0  77   0 ...   0   0   0]
#  [  0   0  98 ...   0   0   0]
#  ...
#  [  0   0   0 ... 109   0   0]
#  [  0   0   0 ...   1 113   0]
#  [  0   1   0 ...   0   0  95]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       105
#            1       0.79      0.86      0.82        90
#            2       0.98      1.00      0.99        98
#            3       0.91      0.89      0.90       100
#            4       0.93      0.97      0.95        86
#            5       0.98      0.83      0.90        98
#            6       0.99      1.00      0.99        97
#            7       0.90      0.96      0.93       101
#            8       0.96      0.97      0.97       105
#            9       0.88      0.94      0.91        99
#           10       0.85      0.91      0.88       102
#           11       0.91      0.96      0.93       102
# ...

# %%
#regresion of averageprice

# %%
# Out:
#    AveragePrice  Total Volume       4046       4225      4770  Total Bags  \
# 0          1.33     40.049235  10.120997  37.903460  3.638275   20.564634
# 1          1.35     38.001150   8.768933  35.473513  3.878204   21.183249
# 2          0.93     49.079175   9.262632  47.790416  5.072283   20.120399
# 3          1.08     42.906983  10.421946  41.597133  4.171309   17.978534
# 4          1.28     37.093893   9.800999  35.260208  4.231732   18.355039
#
#    Small Bags  Large Bags  XLarge Bags  type
# 0   20.490870    4.534711          0.0     0
# 1   21.110581    4.602425          0.0     0
# 2   20.035113    4.689671          0.0     0
# 3   17.839520    5.114173          0.0     0
# 4   18.157325    5.825433          0.0     0

# %%
y1=dfn['AveragePrice']
x1=dfn.iloc[:,2:12]

# %%
x1.head()
# Out:
#    Total Volume       4046       4225      4770  Total Bags  Small Bags  \
# 0     40.049235  10.120997  37.903460  3.638275   20.564634   20.490870
# 1     38.001150   8.768933  35.473513  3.878204   21.183249   21.110581
# 2     49.079175   9.262632  47.790416  5.072283   20.120399   20.035113
# 3     42.906983  10.421946  41.597133  4.171309   17.978534   17.839520
# 4     37.093893   9.800999  35.260208  4.231732   18.355039   18.157325
#
#    Large Bags  XLarge Bags  type  year
# 0    4.534711          0.0     0  2015
# 1    4.602425          0.0     0  2015
# 2    4.689671          0.0     0  2015
# 3    5.114173          0.0     0  2015
# 4    5.825433          0.0     0  2015

# %%
y1.head()
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
x1.shape
# Out:
# (17651, 10)

# %%
y1.shape
# Out:
# (17651,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

from sklearn.linear_model import LinearRegression

# %%
maxaccu=0
maxrs=0
for i in range(1,200):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=30,random_state=i)
    lr=LinearRegression()
    lr.fit(x1_train,y1_train)
    pred_lr=lr.predict(x1_test)
    acc=r2_score(y1_test,pred_lr)
    if acc>maxaccu:
        maxaccu=acc
        maxrs=i
print("maximum r2 score is",maxaccu,"on random state",maxrs)
# Out:
# maximum r2 score is 0.7270016986184719 on random state 31

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as kNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor 
from sklearn.svm import SVR

# %%
lr=LinearRegression()
lr.fit(x1_train,y1_train)
pred_lr=lr.predict(x1_test)
pred_train=lr.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_lr))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_lr))
print('mean squared error:',mean_squared_error(y1_test,pred_lr))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_lr)))
# Out:
# r2_score: 0.5638308043435027
# r2_score on training data: 50.45051456398447
# mean_absolute_error: 0.20673455490375067
# mean squared error: 0.07514245361579798
# root mean squared error: 0.27412123889950224

# %%
from sklearn.neighbors import KNeighborsRegressor as KNN
knn=KNN()
knn.fit(x1_train,y1_train)
pred_knn=knn.predict(x1_test)
pred_train=knn.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_knn))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_knn))
print('mean squared error:',mean_squared_error(y1_test,pred_knn))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_knn)))
# Out:
# r2_score: 0.7751389225696934
# r2_score on training data: 86.59610246884972
# mean_absolute_error: 0.13946666666666668
# mean squared error: 0.03873866666666668
# root mean squared error: 0.1968214080497004

# %%
ls=Lasso()
ls.fit(x1_train,y1_train)
pred_ls=ls.predict(x1_test)
pred_train=ls.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_ls))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_ls))
print('mean squared error:',mean_squared_error(y1_test,pred_ls))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_ls)))
# Out:
# r2_score: 0.39484110682962315
# r2_score on training data: 29.160977124578558
# mean_absolute_error: 0.2581771948735302
# mean squared error: 0.10425569827736023
# root mean squared error: 0.32288650990303114

# %% [markdown]
# rd=Ridge()
# rd.fit(x_train,y_train)
# pred_rd=rd.predict(x_test)
# pred_train=rd.predict(x_train)
# print('r2_score:',r2_score(y_test,pred_rd))
# print('r2_score on training data:',r2_score(y_train,pred_train)*100)
# print('mean_absolute_error:',mean_absolute_error(y_test,pred_rd))
# print('mean squared error:',mean_squared_error(y_test,pred_rd))
# print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred_rd)))

# %%
rd=Ridge()
rd.fit(x1_train,y1_train)
pred_rd=rd.predict(x1_test)
pred_train=rd.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_rd))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_rd))
print('mean squared error:',mean_squared_error(y1_test,pred_rd))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_rd)))
# Out:
# r2_score: 0.5638273743015245
# r2_score on training data: 50.4505116504703
# mean_absolute_error: 0.20673276476746308
# mean squared error: 0.07514304453733213
# root mean squared error: 0.27412231674442733

# %%
ad=AdaBoostRegressor()
ad.fit(x1_train,y1_train)
pred_ad=ad.predict(x1_test)
pred_train=ad.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_ad))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_ad))
print('mean squared error:',mean_squared_error(y1_test,pred_ad))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_ad)))
# Out:
# r2_score: 0.5809454273741412
# r2_score on training data: 50.34677959861125
# mean_absolute_error: 0.1982195818614812
# mean squared error: 0.07219397678607607
# root mean squared error: 0.26868936857657033

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x1_train,y1_train)
pred_gbr=gbr.predict(x1_test)
pred_train=gbr.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_gbr))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_gbr))
print('mean squared error:',mean_squared_error(y1_test,pred_gbr))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_gbr)))
# Out:
# r2_score: 0.5665858282211358
# r2_score on training data: 66.75144603059826
# mean_absolute_error: 0.18742806148778568
# mean squared error: 0.07466782299997957
# root mean squared error: 0.2732541362907057

# %%
svc=SVR()
svc.fit(x1_train,y1_train)
pred_svc=svc.predict(x1_test)
pred_train=svc.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_svc))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_svc))
print('mean squared error:',mean_squared_error(y1_test,pred_svc))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_svc)))
# Out:
# r2_score: 0.4572279817122007
# r2_score on training data: 36.17247689370069
# mean_absolute_error: 0.24195891116647697
# mean squared error: 0.09350779838258956
# root mean squared error: 0.3057904484816188

# %%
rfr=RandomForestRegressor()
rfr.fit(x1_train,y1_train)
pred_rfr=rfr.predict(x1_test)
pred_train=rfr.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_rfr))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_rfr))
print('mean squared error:',mean_squared_error(y1_test,pred_rfr))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_rfr)))
# Out:
# r2_score: 0.5250217780799018
# r2_score on training data: 97.50033479276594
# mean_absolute_error: 0.15669666666666648
# mean squared error: 0.08182840366666669
# root mean squared error: 0.2860566441575282

# %%
#cross validation score

# %%
score=cross_val_score(knn,x1_train,y1_train)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',r2_score(y1_test,pred_knn)-score.mean())
# Out:
# [0.77199209 0.76978618 0.77407175 0.77491624 0.78897175]
# 0.775947601465406
# difference between accuracy score and cross val score is -0.0008086788957125668

# %%
score=cross_val_score(gbr,x1_train,y1_train)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',r2_score(y1_test,pred_gbr)-score.mean())
# Out:
# [0.65320808 0.64554948 0.65010609 0.64206297 0.65673359]
# 0.6495320434269315
# difference between accuracy score and cross val score is -0.0829462152057957

# %%
score=cross_val_score(lr,x1_train,y1_train)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',r2_score(y1_test,pred_lr)-score.mean())
# Out:
# [0.50211055 0.49581722 0.5099517  0.4971153  0.51451648]
# 0.5039022512102524
# difference between accuracy score and cross val score is 0.059928553133250295

# %%
score=cross_val_score(rfr,x1_train,y1_train)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',r2_score(y1_test,pred_rfr)-score.mean())
# Out:
# [0.81125719 0.81314859 0.81077381 0.80868696 0.819999  ]
# 0.8127731114902836
# difference between accuracy score and cross val score is -0.28775133341038184

# %%
score=cross_val_score(ad,x_train,y_train)
print(score)
print(score.mean())
print('difference between accuracy score and cross val score is',r2_score(y_test,pred_ad)-score.mean())
# Out:
# [0.0949592  0.10596243 0.12622705 0.11413812 0.10394448]
# 0.10904625516617983
# difference between accuracy score and cross val score is -2.9439846170589448

# %%
from sklearn.model_selection import GridSearchCV 
parameters = {"leaf_size":list(range(1,50)),"random_state":[10,50,200],"p":[1,2],"n_kneighbors":list(range(1,30))}
knn=KNN()
knn=GridSearchCV(knn,parameters,cv=5)
knn.fit(x_train,y_train)
knn.best_params_
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3500\831776955.py in <module>
#       1 from sklearn.model_selection import GridSearchCV
# ----> 2 parameters = {"leaf_size":list(range(1,50)),"random_state":[10,50,200],"p":[1,2],"n_kneighbors":list(range(1,30))}
#       3 knn=KNN()
#       4 knn=GridSearchCV(knn,parameters,cv=5)
#       5 knn.fit(x_train,y_train)
#
# TypeError: 'list' object is not callable

# %%
final_model_R=KNN()
final_model_R.fit(x1_train,y1_train)
pred_knn=final_model_R.predict(x1_test)
pred_train=final_model_R.predict(x1_train)
print('r2_score:',r2_score(y1_test,pred_knn))
print('r2_score on training data:',r2_score(y1_train,pred_train)*100)
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_knn))
print('mean squared error:',mean_squared_error(y1_test,pred_knn))
print('root mean squared error:',np.sqrt(mean_squared_error(y1_test,pred_knn)))
# Out:
# r2_score: 0.7751389225696934
# r2_score on training data: 86.59610246884972
# mean_absolute_error: 0.13946666666666668
# mean squared error: 0.03873866666666668
# root mean squared error: 0.1968214080497004

# %%
import joblib
joblib.dump(final_model,"avacoda.pkl")
# Out:
# ['avacoda.pkl']

# %%
loaded_model=joblib.load("avacoda.pkl")
